# %% [markdown]
# ## Exercise: Scientific Computing – Brainstorming
#
# ### Step 1: Individual Brainstorm *(5 minutes)*
#
# **Think about the following questions:**
#
# - What words or concepts come to mind when you hear **“scientific computing”**?
# - What do you hope to learn in this course?
#
# Write down **5–10 words or short phrases**.
#
# ---
#
# ### My Answers
#
# #### Words
#
# - Algorithms
# - Efficiency
# - Scalability
# - Numerical methods
# - Numerical stability
# - Floating point error
# - Stability
# - Reproducibility
# - Verification
# - Validation
# - High-performance computing
# - Parallelism
# - optimization
#
# #### What i hope to learn
#
# - Turn math & models into reliable code
# - Numerical thinking
# - Good scientific habits
# - core computational techniques
# - Performance awareness

# %% [markdown]
# #### Mandelbrot Set Introduction

# %%
import time
import matplotlib.pyplot as plt
import statistics
from mandelbrot_naive import compute_mandelbrot_naive, visualize_mandelbrot, benchmark



# Main execution
if __name__ == "__main__":   

    t, M = benchmark(compute_mandelbrot_naive,100, 1024, 1024, n_runs=3)
    visualize_mandelbrot(M)
# Out:
# Median: 3.4473s (min=3.4424, max=3.4863)
